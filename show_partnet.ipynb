# %%
import pathlib
import h5py
import numpy as np
from plotly import graph_objects as go
import plotly.io as pio

# %%
pio.templates.default = "plotly_dark"

# %%
# %load_ext autoreload
# %autoreload 2

from training.data.partnet import HdfIO

# %%
file = h5py.File(r"D:\Datasets\compressed_partnet\train.h5", "r")

# %%
file.keys()
# Out:
# <KeysViewHDF5 ['data', 'data_num', 'label_seg']>

# %%
samples = file["data"][:10]

# %%
seg_map = file["label_seg"][:10]

# %%
file.close()

# %%
seg_map[8]
# Out:
# array([0, 1, 1, ..., 1, 1, 1], dtype=uint8)

# %%
samples.shape
# Out:
# (10, 4096, 3)

# %%
seg_map[index]
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=uint8)

# %%
seg_map[3]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
index = 8

figure = go.Figure(
    data=[
        go.Scatter3d(
        x=samples[index, :, 0],
        y=samples[index, :, 1],
        z=samples[index, :, 2],
        marker=dict(
            color=seg_map[index],
            size=2
        ),
        mode="markers")
    ],
    layout=dict(scene=dict(aspectmode="data"))
)

# %%
figure.show()
